# %%
import pandas as pd
import numpy as np

# %%
file_path = "ConfirmedGlobalJune9.csv"
confirmg_df = pd.read_csv(file_path)
confirmg_df = confirmg_df.copy()
confirmg_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  \
# 0        0        0        0  ...    14525    15205   15750   16509   17267
# 1        0        0        0  ...     1122     1137    1143    1164    1184
# 2        0        0        0  ...     9267     9394    9513    9626    9733
# 3        0        0        0  ...      764      764     765     844     851
# 4        0        0        0  ...       84       86      86      86      86
#
#    6/4/20  6/5/20  6/6/20  6/7/20  6/8/20
# ...

# %%
file_path = "ConfirmedUSJune9.csv"
confirmu_df = pd.read_csv(file_path)
confirmu_df = confirmu_df.copy()
confirmu_df.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  \
# 0 -14.2710 -170.1320  ...       0        0       0       0       0       0
# 1  13.4443  144.7937  ...     172      172     175     175     177     179
# 2  15.0979  145.6739  ...      22       22      22      23      24      26
# 3  18.2208  -66.5901  ...    3718     3776    3873    3935    4023    4508
# 4  18.3358  -64.8963  ...      69       69      70      70      70      71
#
#    6/5/20  6/6/20  6/7/20  6/8/20
# ...

# %%
file_path = "DeathGlobalJune9.csv"
deathg_df = pd.read_csv(file_path)
deathg_df = deathg_df.copy()
deathg_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  \
# 0        0        0        0  ...      249      257     265     270     294
# 1        0        0        0  ...       33       33      33      33      33
# 2        0        0        0  ...      646      653     661     667     673
# 3        0        0        0  ...       51       51      51      51      51
# 4        0        0        0  ...        4        4       4       4       4
#
#    6/4/20  6/5/20  6/6/20  6/7/20  6/8/20
# ...

# %%
file_path = "DeathUSJune9.csv"
deathu_df = pd.read_csv(file_path)
deathu_df = deathu_df.copy()
deathu_df.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  \
# 0 -14.2710 -170.1320  ...       0        0       0       0       0       0
# 1  13.4443  144.7937  ...       5        5       5       5       5       5
# 2  15.0979  145.6739  ...       2        2       2       2       2       2
# 3  18.2208  -66.5901  ...     133      136     136     138     140     140
# 4  18.3358  -64.8963  ...       6        6       6       6       6       6
#
#    6/5/20  6/6/20  6/7/20  6/8/20
# ...

# %%
file_path = "RecoveredGlobalJune9.csv"
recoveredg_df = pd.read_csv(file_path)
recoveredg_df = recoveredg_df.copy()
recoveredg_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  \
# 0        0        0        0  ...     1303     1328    1428    1450    1522
# 1        0        0        0  ...      857      872     877     891     898
# 2        0        0        0  ...     5549     5748    5894    6067    6218
# 3        0        0        0  ...      692      694     698     733     735
# 4        0        0        0  ...       18       18      18      18      18
#
#    6/4/20  6/5/20  6/6/20  6/7/20  6/8/20
# ...
